# %%
import pandas as pd

# %%
from matplotlib import pyplot as plt

# %%
x = [1,2,3,5,8]
y = [20,31,35,59,44]
z = [40,31,25,21,11]

# %%
plt.plot(x,y)
plt.plot(x,z)
plt.title("Test data visualization")
plt.xlabel("x")
plt.ylabel("y")
plt.legend(["this is y", "this is z"])
plt.show()

# %%
sample_data = pd.read_csv("data/sample_data.csv")

# %%
population_per_countries = pd.read_csv("data/countries.csv")

# %%
uk_countries = population_per_countries[population_per_countries.country == "United Kingdom"]

# %%
plt.plot(uk_countries.year, uk_countries.population / 10**6)
plt.xlabel("YEAR")
plt.ylabel("POPULATION (M)")
plt.title("Population variation of UK")
plt.show()

# %%
countries_list = []
for i in population_per_countries.country:
    if i not in countries_list:
        countries_list.append(i)

# %%
countries_list
# Out:
# ['Afghanistan',
#  'Albania',
#  'Algeria',
#  'Angola',
#  'Argentina',
#  'Australia',
#  'Austria',
#  'Bahrain',
#  'Bangladesh',
#  'Belgium',
#  'Benin',
#  'Bolivia',
#  'Bosnia and Herzegovina',
#  'Botswana',
#  'Brazil',
#  'Bulgaria',
#  'Burkina Faso',
#  'Burundi',
#  'Cambodia',
#  'Cameroon',
#  'Canada',
#  'Central African Republic',
#  'Chad',
#  'Chile',
#  'China',
#  'Colombia',
#  'Comoros',
#  'Congo, Dem. Rep.',
#  'Congo, Rep.',
#  'Costa Rica',
#  "Cote d'Ivoire",
#  'Croatia',
#  'Cuba',
#  'Czech Republic',
#  'Denmark',
#  'Djibouti',
#  'Dominican Republic',
#  'Ecuador',
#  'Egypt',
#  'El Salvador',
#  'Equatorial Guinea',
#  'Eritrea',
#  'Ethiopia',
#  'Finland',
#  'France',
#  'Gabon',
#  'Gambia',
#  'Germany',
#  'Ghana',
#  'Greece',
#  'Guatemala',
#  'Guinea',
#  'Guinea-Bissau',
#  'Haiti',
#  'Honduras',
#  'Hong Kong, China',
#  'Hungary',
#  'Iceland',
#  'India',
#  'Indonesia',
#  'Iran',
#  'Iraq',
#  'Ireland',
#  'Israel',
# ...

# %%
population_1952 = population_per_countries[population_per_countries.year == 1952]
population_1952
# Out:
#                  country  year  population
# 0            Afghanistan  1952     8425333
# 12               Albania  1952     1282697
# 24               Algeria  1952     9279525
# 36                Angola  1952     4232095
# 48             Argentina  1952    17876956
# ...                  ...   ...         ...
# 1644             Vietnam  1952    26246839
# 1656  West Bank and Gaza  1952     1030585
# 1668         Yemen, Rep.  1952     4963829
# 1680              Zambia  1952     2672000
# 1692            Zimbabwe  1952     3080907
#
# [142 rows x 3 columns]

# %%
most_populate_countries = population_1952["population"].nlargest(3)

# %%
country_popul = pd.DataFrame({"population":list(most_populate_countries)},index=countries_list[:3])

# %%
country_popul.plot(kind="pie", y="population")
# Out:
# <AxesSubplot:ylabel='population'>

# %%
most_populate_countries.plot.bar(x='country', y=most_populate_countries[population],rot=0)
# Out:
# <AxesSubplot:>
